# %% [markdown]
# # 가. 묶음 자료형 (계속)

# %% [markdown]
# ## 1. 딕셔너리

# %% [markdown]
# ### 가) 딕셔너리 개요

# %% [markdown]
# * Key-Value 쌍 구조: 데이터가 {Key: Value}의 형태(1쌍)로 저장
#
# * Key의 중복 불가: Key는 유일해야 하며 중복될 수 없으나, Value는 중복이 가능
#
# * Key를 통한 데이터 접근: 순서(인덱스)가 따로 없으며, 인덱스 대신 Key를 이용하여 데이터를 가져옴

# %%
a = {}
b = {"name" : "JH"}
c = {1 : "이재현", 2 : "백수"}
print(a)
print(b)
print(c)
# Out:
# {}
# {'name': 'JH'}
# {1: '이재현', 2: '백수'}

# %% [markdown]
# ### 나) 딕셔너리 생성

# %% [markdown]
# 중괄호 {}를 사용하며, Key와 Value는 콜론 :으로 구분
#
# * a = {}
#
# * b = {"name" : "JH"}
#
# * c = {1 : "이재현", 2 : "백수"}

# %%
my_info = {"name" : "이재현", "age" : 26, "phone" : "010-4131-1852"}
print(my_info)
# Out:
# {'name': '이재현', 'age': 26, 'phone': '010-4131-1852'}

# %% [markdown]
# ### 다) 딕셔너리 값 가져오기

# %%
print(my_info["phone"])
# Out:
# 010-4131-1852

# %% [markdown]
# ### 라) 딕셔너리 데이터 추가

# %%
my_info["birth"] = "2001. 10. 27."
print(my_info)
# Out:
# {'name': '이재현', 'age': 26, 'phone': '010-4131-1852', 'birth': '2001. 10. 27.'}

# %%
dict_test = {"제목" : "청춘의 끝에서 시작을 부르다"}
print(dict_test)
# Out:
# {'제목': '청춘의 끝에서 시작을 부르다'}

# %%
dict_test["아티스트"] = "혜성"
dict_test["발매일"] = "2026. 06. 10. "
print(dict_test)
# Out:
# {'제목': '청춘의 끝에서 시작을 부르다', '아티스트': '혜성', '발매일': '2026. 06. 10. '}

# %%
print(f"아티스트 {dict_test["아티스트"]}의 노래 {dict_test["제목"]}의 발매일은 {dict_test["발매일"]}입니다.")
# Out:
# 아티스트 혜성의 노래 청춘의 끝에서 시작을 부르다의 발매일은 2026. 06. 10. 입니다.

# %% [markdown]
# ## 마) 데이터 삭제

# %%
my_info = {"name" : "이재현", "age" : 26, "phone" : "010-4131-1852"}
print(my_info)
del my_info["phone"]
print(my_info)
# Out:
# {'name': '이재현', 'age': 26, 'phone': '010-4131-1852'}
# {'name': '이재현', 'age': 26}

# %% [markdown]
# ## 바) 데이터 수정

# %%
dict1 = {1 : "이재현", 2 : "백수"}
print(dict1)
dict1[2] = "취업준비생"
print(dict1)
# Out:
# {1: '이재현', 2: '백수'}
# {1: '이재현', 2: '취업준비생'}

# %% [markdown]
# ### 리스트 보충 : 데이터 추가

# %% [markdown]
# * list.append(data)

# %%
list_data = [10, 20, 30, 40]
print(f"최초 리스트 = {list_data}")
list_data.append(50)
print(f"추가된 리스트 = {list_data}")
# Out:
# 최초 리스트 = [10, 20, 30, 40]
# 추가된 리스트 = [10, 20, 30, 40, 50]

# %% [markdown]
# # 연습문제

# %% [markdown]
# ## 1. 나만의 인물 사전 만들기
#
# ### 좋아하는 연예인의 이름(name)과 직업(job)을 key로 하는 딕셔너리 my_star를 만들고,
# ### 딕셔너리 전체를 출력하는 코드를 작성하세요.

# %%
my_star = {"name" : "음율", "job" : "가수"}
print(my_star)
# Out:
# {'name': '음율', 'job': '가수'}

# %% [markdown]
# ## 2. 딕셔너리 값 추출하여 문장 만들기
# ### 나의 도시(city)와 인구(population) 정보가 담긴 my_city 딕셔너리가 있습니다.
# ### 각 key를 이용해 값을 추출하고,
# ### f-string을 사용하여 "제가 사는 곳은 OOO이고, 인구는 OO만 명입니다."
# ### 형식으로 출력하는 코드를 작성하세요.
#
# ### my_city = {'city': '서울', 'population': 940}

# %%
my_city = {'city': '서울', 'population': 940}
print(f"제가 사는 곳은 {my_city["city"]}이고, 인구는 {my_city["population"]}만 명입니다.")
# Out:
# 제가 사는 곳은 서울이고, 인구는 940만 명입니다.

# %% [markdown]
# ## 3. 새로운 정보 추가하기
# ### 상품의 이름과 가격이 저장된 product 딕셔너리에, key가 'stock'이고 value가 100인 재고
# ### 정보를 추가한 후, 정보가 추가된 product 딕셔너리 전체를 출력하는 코드를 작성하세요.
#
# ### product = {'name': '커피', 'price': 5000}

# %%
product = {'name': '커피', 'price': 5000}
product["stock"] = 100
print(product)
# Out:
# {'name': '커피', 'price': 5000, 'stock': 100}

# %% [markdown]
# ## 4. 기존 정보 수정하기
# ### 문제 3의 product 딕셔너리에서, 가격('price')이 5000원에서 5500원으로 인상되었습니다.
# ### 가격 정보를 수정하고, 수정된 product 딕셔너리 전체를 출력하는 코드를 작성하세요.

# %%
product["price"] = 5500
print(product)
# Out:
# {'name': '커피', 'price': 5500, 'stock': 100}

# %% [markdown]
# ## 5. 리스트를 값으로 갖는 딕셔너리 만들기
# ### 영화 제목(title)과 출연 배우 목록(actors)을 key로 하는 딕셔너리 movie를 만드세요.
# ### 출연 배우는 2명 이상으로 하여 리스트 자료구조를 value로 사용해야 합니다.
# ### 딕셔너리를 만든 후 전체를 출력하는 코드를 작성하세요.

# %%
movie_info = {"title" : "호프", "actors" : ["황정민", "조인성", "정호연"]}
print(movie_info)
# Out:
# {'title': '호프', 'actors': ['황정민', '조인성', '정호연']}

# %% [markdown]
# ## 2. 튜플

# %%
t = (1, 2, 3)
print(t[0])
# t[1] = 5  <- TypeError: 'tuple' object does not support item assignment
# Out:
# 1

# %% [markdown]
# # 나. 기본 자료형 (계속)

# %% [markdown]
# ## 1. 숫자형 자료형
# ### 1) 정수형 (int, Integer): 소수점이 없는 수 (양의 정수, 음의 정수, 0)
#   * 생활 예시: 나이, 제품 수량, 방문자 수
# ### 2) 실수형 (float, Floating-point): 소수점이 포함된 수
#   * 생활 예시: 키/몸무게, 시력, 환율, 할인율
# ### 3) 연산자
#   * 기본 사칙 연산 (+, -, *, /): 두 숫자형 데이터 간의 가감승제 연산 수행

# %%
num1 = 123
num2 = 1.2
summ = num1 + num2
sub = num1 - num2
multi = num1 * num2
div = num1 / num2
print(f"{num1} + {num2} = {summ}")
print(f"{num1} - {num2} = {sub}")
print(f"{num1} * {num2} = {multi}")
print(f"{num1} / {num2} = {div}")
# Out:
# 123 + 1.2 = 124.2
# 123 - 1.2 = 121.8
# 123 * 1.2 = 147.6
# 123 / 1.2 = 102.5

# %% [markdown]
#   * 특수 연산자 (**, //, %)
#     * 제곱 연산자 ( ** ): x의 y제곱 계산, 예) 3의 4제곱 (3**4)
#     * 나머지 연산자 (%): 나눗셈 후 나머지만 추출
#     * 몫 연산자 (//): 나눗셈 후 소수점 아래를 버리고 몫(정수)만 추출

# %%
power = num1 ** num2
remain = num1 % num2
quot = num1 // num2
print(f"{num1} ** {num2} = {power}")
print(f"{num1} % {num2} = {remain}")
print(f"{num1} // {num2} = {quot}")
# Out:
# 123 ** 1.2 = 322.02243803234467
# 123 % 1.2 = 0.6000000000000045
# 123 // 1.2 = 102.0

# %% [markdown]
# ## 2. 문자열 자료형
# ### 가) 개요
#   * 하나 이상의 연속된 문자로 구성된 데이터 형태
#   * 각 문자마다 위치(인덱스)를 가짐
# ### 나) 생성 방식
#   * 단일 줄: 따옴표(' 또는 ")로 감싸서 생성
#   * 여러 줄: 작은따옴표/큰따옴표 3개(''' 또는 """)를 사용하여 줄 바꿈이 포함된 문자열을 생성

# %%
string1 = 'a'
string2 = 'apple'
string3 = "banana"
multi_line = """
this is line number1
this is line number2
this is line number3
this is line number4
"""
print(string1, string2, string3)
print(multi_line)
# Out:
# a apple banana
#
# this is line number1
# this is line number2
# this is line number3
# this is line number4

# %% [markdown]
# ### 다) 인덱싱, 슬라이싱
#   * string[0]처럼 위치 번호를 지정해 특정 위치의 문자를 추출
#   * string[start:stop] 형태로 원하는 범위의 문자열을 잘라냄

# %%
string4 = "abcdefg"
print(string4[3])
print(string4[3:6])
# Out:
# d
# def

# %% [markdown]
# ### 라) 연산
#   * "+" 연산자를 사용해 문자열끼리 연결 가능

# %%
string5 = "hijklmnop"
print(string4 + string5)
# Out:
# abcdefghijklmnop

# %% [markdown]
#   * "*" 연산자를 사용해 문자열 반복 가능

# %%
string6 = "안녕"
print(string6 * 3)
print("-" * 80)
# Out:
# 안녕안녕안녕
# --------------------------------------------------------------------------------

# %% [markdown]
# ## 3. 블리언 자료형
# ### 가) 값의 종류 : True, False
# ### 나) 기능 : 긍정, 부정을 표현
# ### 다) 특징
#   * 문자열이지만 문자열 표시(X) → 기능이 사전에 정의된 예약어
#   * 문자열의 형태이지만 연산(+,-,*,/)이 가능
#   * 연산 시 → 문자가 아닌 수로 인식 → True(1), False(0)

# %% [markdown]
# # 파이썬 자료형 종합 연습문제

# %% [markdown]
# ## 1. 변수와 f-string을 이용한 출력 변수 name에 '홍길동', age에 25를 저장한 후, f-string 접두사를 사용하여 "제 이름은 홍길동이고, 나이는 25세입니다." 형식으로 문장을 출력하는 코드를 작성하세요.

# %%
name = "홍길동"
age = 25
print(f"제 이름은 {name}이고, 나이는 {age}세입니다.")
# Out:
# 제 이름은 홍길동이고, 나이는 25세입니다.

# %% [markdown]
# ## 2. 숫자형 사칙 연산 변수 num1에 15, num2에 4를 할당하고, 두 수의 덧셈, 뺄셈, 곱셈, 나눗셈 결과를 각각 출력하는 코드를 작성하세요.

# %%
num1 = 15
num2 = 4
sum = num1 + num2
sub = num1 - num2
multi = num1 * num2
div = num1 / num2
print(f"{num1} + {num2} = {sum}")
print(f"{num1} - {num2} = {sub}")
print(f"{num1} * {num2} = {multi}")
print(f"{num1} / {num2} = {div}")
# Out:
# 15 + 4 = 19
# 15 - 4 = 11
# 15 * 4 = 60
# 15 / 4 = 3.75

# %% [markdown]
# ## 3. 제곱 연산자(**) 활용 변수 base에 2, exponent에 10을 저장한 뒤, 제곱 연산자(**)를 사용하여 2의 10제곱 값을 계산하여 출력하는 코드를 작성하세요.

# %%
base, exponent = 2, 10
print(f"{base}^{exponent} = {base ** exponent}")
# Out:
# 2^10 = 1024

# %% [markdown]
# ## 4. 몫(//)과 나머지(%) 연산자 17을 5로 나누었을 때의 몫과 나머지를 각각 몫 연산자(//)와 나머지 연산자(%)를 이용해 구하고 출력하는 코드를 작성하세요.

# %%
num1, num2 = 17, 5
quot = 17 // 5
remain = 17 % 5
print(f"{num1} // {num2} = {quot}")
print(f"{num1} % {num2} = {remain}")
# Out:
# 17 // 5 = 3
# 17 % 5 = 2

# %% [markdown]
# ## 5. 불리언 수치 연산 특성 불리언 값 bool_data1 = True, bool_data2 = False를 생성하고, 두 값을 덧셈 연산(bool_data1 + bool_data1 + bool_data2)한 결과를 출력하는 코드를 작성하세요.

# %%
bool_data1 = True
bool_data2 = False
result_bool = bool_data1 + bool_data1 + bool_data2
print(f"{bool_data1} + {bool_data1} + {bool_data2} = {result_bool}")
# Out:
# True + True + False = 2

# %% [markdown]
# ## 6. 여러 줄 문자열 생성과 길이 측정 작은따옴표 3개(''')를 사용하여 3줄 이상의 임의의 문자열 변수 multi_str을 생성하고, len() 함수를 사용해 전체 글자 수를 출력하는 코드를 작성하세요.

# %%
multi_str = """
밤새 잠 못 든 이른 새벽 아래
멈춰진 시간 속 널 기억하고
웃으며 말을 건네오는 바보 같은 상상을 해

닿을 듯 닿지 않아 괴롭던 시간 속에도
홀린 듯 발걸음을 떼었던 기억 속에도
더는 되돌아보지 않아 다짐한 날에도
그저 푸르던 계절로 맴돌아

날 깨워 돌아가는 시곗바늘 초침 소리가
아 너의 목소리에 멈춰 더는 들리지가 않아

날 따라 흘러가는 지난날의 파도 소리가
아 그만 네가 있던 추억들 속에 날 데려가잖아

밤새 잠 못 든 이른 새벽 아래
멈춰진 시간 속 널 기억하고
이 밤이 너와 닿는다면 그동안 달라진 날 알아봐줄래

또 한 번 또다시 불러봐도
흩어진 네모습은 멀어지고
의미 없이 지나온 날들은
모른 채 눈을 감아 너에게 닿을 수 있기를

날 깨워 돌아가는 시곗바늘 초침 소리가
아 너의 목소리에 멈춰 더는 들리지가 않아

날 따라 흘러가는 지난 날의 파도 소리가
아 그만 네가 있던 추억들 속에 날 데려가잖아

밤새 잠 못 든 이른 새벽 아래
멈춰진 시간 속 널 기억하고
이 밤이 너와 닿는다면 그동안 갈라진 날 알아봐줄래

또 한 번 또다시 불러봐도
흩어진 네 모습은 멀어지고
의미 없이 지나온 날들은
모른 채 눈을 감아 너에게 닿을 수 있기를

처음 너를 만났던 날에
네 손잡고 걸었던 날에
마주 보며 웃은 그 기억들은
이제 감춰진 시간 속에

처음 우리 다퉜던 날에
네 품에서 잠에 든 날에
너로 인해 슬픈 기억들은
모른채 눈을 감아 너에게 닿을 수 있기를
"""
print(len(multi_str))
# Out:
# 717

# %% [markdown]
# ### 7.  문자열 인덱싱 문자열 text = "파이썬프로그래밍"에서 인덱싱을 통해 첫 번째 글자인 '파'와 마지막 글자인 '밍'을 각각 추출하여 출력하는 코드를 작성하세요.

# %%
text = "파이썬프로그래밍"
print(f"파이썬프로그래밍의 첫 글자는 '{text[0]}'이고 마지막 글자는 '{text[-1]}'입니다")
# Out:
# 파이썬프로그래밍의 첫 글자는 '파'이고 마지막 글자는 '밍'입니다

# %% [markdown]
# ## 8. 문자열 슬라이싱 문자열 string = "문자열은 인덱싱과 슬라이싱이 가능하다"에서 슬라이싱을 활용하여 "인덱싱과 슬라이싱" 부분만 추출하여 출력하는 코드를 작성하세요.

# %%
string = "문자열은 인덱싱과 슬라이싱이 가능하다"
print(string[5:14])
# Out:
# 인덱싱과 슬라이싱

# %% [markdown]
# ## 9. 문자열 연결과 반복 str1 = "Python", str2 = " ", str3 = "Fun"을 덧셈 연산자로 연결하여 "Python Fun"을 출력하고, 곱셈 연산자를 사용하여 "=" 문자를 20번 반복한 구분선을 출력하는 코드를 작성하세요.

# %%
str1, str2, str3 = "Python", " ", "Fun"
print(str1 + str2 + str3)
print("=" * 20)
# Out:
# Python Fun
# ...

# %% [markdown]
# ## 10. 리스트 기본 인덱싱 numbers = [10, 20, 30, 40, 50] 리스트에서 세 번째 원소(30)와 다섯 번째 원소(50)를 인덱싱하여 두 수의 합을 출력하는 코드를 작성하세요.

# %%
numbers = [10, 20, 30, 40, 50]
print(numbers[2] + numbers[4])
# Out:
# 80

# %% [markdown]
# ## 11. 중첩 리스트 인덱싱 리스트 nested_list = [1, 2, 3, ['a', 'b', 'c']]에서 문자 'b'만 인덱싱으로 추출하여 출력하는 코드를 작성하세요.

# %%
nested_list = [1, 2, 3, ['a', 'b', 'c']]
print(nested_list[3][1])
# Out:
# b

# %% [markdown]
# ## 12. 리스트 슬라이싱 data_list = [0, 10, 20, 30, 40, 50]에서 [20, 30, 40] 부분 리스트만 슬라이싱하여 출력하는 코드를 작성하세요.

# %%
data_list = [0, 10, 20, 30, 40, 50]
print(data_list[2:5])
# Out:
# [20, 30, 40]

# %% [markdown]
# ## 13. 튜플 생성 및 인덱싱 원소 1, 2, 3을 갖는 튜플 t = (1, 2, 3)을 생성하고 첫 번째 원소를 출력하는 코드를 작성하세요.

# %%
t = (1, 2, 3)
print(t[0])
# Out:
# 1

# %% [markdown]
# ## 14.  딕셔너리 생성 및 값 추출 Key가 'title', Value가 '파이썬', Key가 'year', Value가 2026인 딕셔너리 movie를 생성하고, Key가 'title'인 Value를 추출하여 출력하는 코드를 작성하세요.

# %%
movie = {"title" : "파이썬", "year" : 2026}
print(movie["title"])
# Out:
# 파이썬

# %% [markdown]
# ## 15. 딕셔너리 데이터 추가 및 수정 빈 딕셔너리 user_info = {}를 만든 후, Key: 'name', Value: 'Alice' 데이터를 추가하고, Key: 'name'의 Value를 'Bob'으로 수정한 뒤 최종 딕셔너리를 출력하는 코드를 작성하세요.

# %%
user_info = {}
user_info["name"] = "Alice"
user_info["name"] = "Bob"
print(user_info)
# Out:
# {'name': 'Bob'}

# %% [markdown]
# ## 16. 딕셔너리와 리스트 인덱싱 융합 person = {'name': 'MH', 'hobbies': ['코딩', '독서', '운동']} 딕셔너리에서 이름과 두 번째 취미('독서')를 각각 추출하여 f-string으로 "MH의 두 번째 취미는 독서입니다." 형식으로 출력하는 코드를 작성하세요.

# %%
person = {'name': 'MH', 'hobbies': ['코딩', '독서', '운동']}
print(f"{person["name"]}의 두번째 취미는 {person['hobbies'][1]}입니다.")
# Out:
# MH의 두번째 취미는 독서입니다.

# %% [markdown]
# ## 17.  리스트와 산술 연산자 융합 scores = [85, 92, 78] 리스트의 세 원소를 모두 더한 합계를 구하고, 3으로 나눈 몫(//)을 이용해 평균 점수(정수)를 구하여 합계와 평균 몫을 각각 출력하는 코드를 작성하세요.

# %%
scores = [85, 92, 78] 
sum = 0
for i in range(len(scores)) :
  sum += scores[i]
avr = sum // len(scores)
print(f"총 합 = {sum}, 평균 = {avr}")
# Out:
# 총 합 = 255, 평균 = 85

# %% [markdown]
# ## 18. 불리언 크기 비교와 딕셔너리 저장 융합 변수 my_money = 15000이 10000보다 큰지 크기 비교한 불리언 결과를 구하여, result_dict = {}의 Key 'is_rich'의 Value로 저장한 후 딕셔너리를 출력하는 코드를 작성하세요.

# %%
my_money = 15000
result_dict = {"is_rich" : (my_money > 10000)}
print(result_dict)
# Out:
# {'is_rich': True}

# %% [markdown]
# ## 19.  문자열 슬라이싱과 리스트 융합 주민등록번호 문자열 pin = "990101-1234567"에서 생년월일 앞 6자리("990101")와 뒤 7자리("1234567")를 슬라이싱하여 추출하고, 두 문자열을 원소로 갖는 리스트 pin_list를 만들어 출력하는 코드를 작성하세요.

# %%
pin = "990101-1234567"
pin_list = pin.split("-")
print(pin_list)
# Out:
# ['990101', '1234567']

# %% [markdown]
# ## 20. 튜플 인덱싱과 제곱 연산자 융합 튜플 dimensions = (3, 4, 5)의 첫 번째 원소(3)의 2제곱과 두 번째 원소(4)의 2제곱의 합을 계산하고, f-string을 이용하여 "계산 결과: 25" 형식으로 출력하는 코드를 작성하세요.

# %%
dimensions = (3, 4, 5)
result = (dimensions[0] ** 2) + (dimensions[1] ** 2)
print(f"계산 결과: {result}")
# Out:
# 계산 결과: 25

# %% [markdown]
# ## 21. 딕셔너리 수정과 나머지 연산자 융합 딕셔너리 item = {'count': 11}의 'count' 값을 12로 수정하고, 수정된 count 값을 2로 나눈 나머지(%)를 구하여 출력하는 코드를 작성하세요.

# %%
item = {'count': 11}
item["count"] = 12
print(item["count"] % 2)
# Out:
# 0

# %% [markdown]
# ## 22. 중첩 리스트와 문자열 슬라이싱 융합 리스트 complex_data = [100, ["Python_Basic", "Data_Analysis"]]에서 인덱싱으로 "Python_Basic"을 찾아낸 후, 슬라이싱을 사용하여 "Python" 단어만 추출하여 출력하는 코드를 작성하세요.

# %%
complex_data = [100, ["Python_Basic", "Data_Analysis"]]
print(complex_data[1][0].split("_")[0])
# Out:
# Python

# %% [markdown]
# ## 23. 불리언 연산과 문자열 곱셈 융합 불리언 변수 b1 = True, b2 = True, b3 = False의 합산 결과를 계산하여 반복 횟수로 사용하고, 문자열 "*"를 해당 횟수만큼 곱하여 출력하는 코드를 작성하세요.

# %%
b1, b2, b3 = True, True, False
print("*" * (b1 + b2 + b3))
# Out:
# **

# %% [markdown]
# ## 24. 리스트와 딕셔너리 구조화 융합 이름 리스트 names = ['박보검', '이찬원']과 직업 리스트 jobs = ['배우', '가수']를 활용하여 {'name': names, 'job': jobs} 형태의 딕셔너리 data를 생성하고 출력하는 코드를 작성하세요.

# %%
names = ['박보검', '이찬원']
jobs = ['배우', '가수']
data = {'name': names, 'job': jobs}
print(data)
# Out:
# {'name': ['박보검', '이찬원'], 'job': ['배우', '가수']}

# %% [markdown]
# ## 25. 튜플과 리스트 비교 응용 튜플 tuple_data = (10, 20, 30) 대신 동일한 원소 [10, 20, 30]를 갖는 리스트 list_data를 생성하고, 첫 번째 원소를 100으로 변경한 후 리스트를 출력하는 코드를 작성하세요 (튜플은 원소를 수정할 수 없음을 주석으로 작성하세요).

# %%
tuple_data = (10, 20, 30)
list_data = [10, 20, 30]
list_data[0] = 100
# tuple_data[0] = 100 <- 튜플은 원소를 수정할 수 없으므로 오류 발생
print(list_data)
# Out:
# [100, 20, 30]
